# %%
# Checking the installed Python version
# !python --version
# Out:
# Python 3.10.12

# %%
# Mounting Google Drive to access the 'TrackFormer' directory and the training data
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# Install the updated requirements from due to Python 3.10 on Colab, adapting the original Python 3.7 setup of the project
# !pip install -r /content/drive/MyDrive/requirements-3-10.txt

# %%
# !pip install sacred --upgrade
# Out:
# ...
#   Using cached jsonpickle-3.3.0-py3-none-any.whl.metadata (8.3 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 108.2/108.2 kB 4.5 MB/s eta 0:00:00
# ...
# Using cached jsonpickle-3.3.0-py3-none-any.whl (42 kB)
# ...
#   Attempting uninstall: jsonpickle
#     Found existing installation: jsonpickle 1.4.1
#     Uninstalling jsonpickle-1.4.1:
#       Successfully uninstalled jsonpickle-1.4.1
#   Attempting uninstall: sacred
#     Found existing installation: sacred 0.8.1
#     Uninstalling sacred-0.8.1:
#       Successfully uninstalled sacred-0.8.1
# ...

# %%
# Adjusting package versions and installing dependencies due to Python version on Colab
# !pip install torch==2.4.0 torchvision==0.19.0
# Out:
# ...
#   Using cached typing_extensions-4.12.2-py3-none-any.whl.metadata (3.0 kB)
# ...
# Using cached typing_extensions-4.12.2-py3-none-any.whl (37 kB)
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 3.7.4.3
#     Uninstalling typing-extensions-3.7.4.3:
#       Successfully uninstalled typing-extensions-3.7.4.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 1.15.0 requires cloudpickle>=2.0.0, but you have cloudpickle 1.6.0 which is incompatible.
# bigframes 1.15.0 requires ipywidgets>=7.7.1, but you have ipywidgets 7.6.3 which is incompatible.
# bigframes 1.15.0 requires requests>=2.27.1, but you have requests 2.23.0 which is incompatible.
# cudf-cu12 24.4.1 requires pandas<2.2.2dev0,>=2.0, but you have pandas 1.5.3 which is incompatible.
# ...

# %%
# !pip3 install -U 'git+https://github.com/timmeinhardt/cocoapi.git#subdirectory=PythonAPI'
# Out:
# ...
#   Cloning https://github.com/timmeinhardt/cocoapi.git to /tmp/pip-req-build-nzc0xxv9
#   Running command git clone --filter=blob:none --quiet https://github.com/timmeinhardt/cocoapi.git /tmp/pip-req-build-nzc0xxv9
#   Resolved https://github.com/timmeinhardt/cocoapi.git to commit 2405d16c53e33887c4b032e99bb3611acf0ba390
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for pycocotools: filename=pycocotools-2.0-cp310-cp310-linux_x86_64.whl size=345349 sha256=7233e041ae6db23e43fcd3d438336eb72b4e749bfd2613c5822680b11ca83316
#   Stored in directory: /tmp/pip-ephem-wheel-cache-srxrgftp/wheels/55/d9/c5/eff4cd65f422e088a36167f16d5795b8748dce037ae149ffed
# Successfully built pycocotools
# ...
#   Attempting uninstall: pycocotools
#     Found existing installation: pycocotools 2.0.8
#     Uninstalling pycocotools-2.0.8:
#       Successfully uninstalled pycocotools-2.0.8
# ...

# %%
# Navigate
# %cd /content/drive/MyDrive/trackformer-main/
# Out:
# /content/drive/MyDrive/trackformer-main

# %%
# Create and install the MultiScaleDeformableAttention package for the current environment
# !python src/trackformer/models/ops/setup.py build --build-base=src/trackformer/models/ops/ install
# Out:
# running build
# running build_ext
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:414: UserWarning: The detected CUDA version (12.2) has a minor version mismatch with the version that was used to compile PyTorch (12.1). Most likely this shouldn't be a problem.
#   warnings.warn(CUDA_MISMATCH_WARN.format(cuda_str_version, torch.version.cuda))
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:424: UserWarning: There are no x86_64-linux-gnu-g++ version bounds defined for CUDA version 12.2
#   warnings.warn(f'There are no {compiler_name} version bounds defined for CUDA version {cuda_str_version}')
# building 'MultiScaleDeformableAttention' extension
# /usr/local/lib/python3.10/dist-packages/torch/utils/cpp_extension.py:1965: UserWarning: TORCH_CUDA_ARCH_LIST is not set, all archs for visible cards are included for compilation.
# If this is not desired, please set os.environ['TORCH_CUDA_ARCH_LIST'].
#   warnings.warn(
# ...

# %%
# This updates deprecated Python types to ensure compatibility with newer numpy versions.
# This is necessary due to changes in the way numpy handles these types from Python 3.7 to 3.10.

import os

def replace_deprecated_python_types(directory, old_type, new_type):
    for root, dirs, files in os.walk(directory):
        for file in files:
            if file.endswith(".py"):
                filepath = os.path.join(root, file)
                with open(filepath, 'r', encoding='utf-8') as file:
                    content = file.read()

                new_content = content.replace(old_type, new_type)

                if new_content != content:
                    with open(filepath, 'w', encoding='utf-8') as file:
                        file.write(new_content)
                    print(f"Updated {filepath}")

directory = "/usr/local/lib/python3.10/dist-packages/pycocotools"
replace_deprecated_python_types(directory, 'np.float', 'float')

directory = "/usr/local/lib/python3.10/dist-packages/motmetrics"
replace_deprecated_python_types(directory, 'np.float', 'float')
replace_deprecated_python_types(directory, 'np.bool', 'bool')
# Out:
# Updated /usr/local/lib/python3.10/dist-packages/pycocotools/cocoeval.py
# Updated /usr/local/lib/python3.10/dist-packages/motmetrics/distances.py
# Updated /usr/local/lib/python3.10/dist-packages/motmetrics/io.py
# Updated /usr/local/lib/python3.10/dist-packages/motmetrics/mot.py

# %%
# 1 encoder/decoder layer
# !python src/train.py with mot17 deformable multi_frame tracking resume=models/mot17_deformable_multi_frame/checkpoint_epoch_50.pth output_dir=models/custom_dataset_deformable/finetuned_layer mot_path_train=data/custom_dataset mot_path_val=data/custom_dataset train_split=train val_split=val enc_layers=1 dec_layers=1 epochs=5
# Out:
# Streaming output truncated to the last 5000 lines.
#  HS_EMBEDSFalse
#  INDICES: False
# POS: False
#  SCORES: False
#  HS_EMBEDSFalse
#  INDICES: False
# POS: False
#  SCORES: False
#  HS_EMBEDSFalse
#  INDICES: False
# POS: False
#  SCORES: False
#  HS_EMBEDSFalse
#  INDICES: False
# POS: False
#  SCORES: False
#  HS_EMBEDSFalse
#  INDICES: False
# POS: tensor([[ 218.3904,  865.2933,  299.7984,  919.8672],
#         [ 447.6073,  843.9783,  514.5606,  912.7113],
#         [  41.6947,  997.0825,   99.4355, 1032.5677],
#         [ 747.6259,  213.5184,  821.9251,  298.1676],
#         [ 548.4594,  634.6727,  614.9792,  723.0834],
#         [ 778.2503,  696.9584,  821.4846,  795.8610],
#         [ 711.0555,  953.4012,  749.6608, 1044.6216],
#         [ 722.8513,  556.9690,  774.2879,  652.5702],
#         [ 659.0571,  352.2084,  731.4424,  410.9263],
#         [ 125.7835,  844.5611,  181.5047,  903.7691],
#         [  87.2432,  486.3821,  143.2871,  549.4799],
# ...

# %%
# 2 encoder/decoder layers
# !python src/train.py with mot17 deformable multi_frame tracking resume=models/mot17_deformable_multi_frame/checkpoint_epoch_50.pth output_dir=models/custom_dataset_deformable/finetuned_layer mot_path_train=data/custom_dataset mot_path_val=data/custom_dataset train_split=train val_split=val enc_layers=2 dec_layers=2 epochs=5
# Out:
# Streaming output truncated to the last 5000 lines.
#         [764.3407,  -1.0189, 819.0186,  53.1229],
#         [117.0036, 938.4869, 183.5635, 994.6025],
#         [469.4107, 842.0701, 528.3837, 909.7537],
#         [722.0762, 546.5994, 779.2598, 646.0289]], device='cuda:0')
#  SCORES: tensor([0.4045, 0.4059, 0.4181, 0.4330, 0.4177, 0.4077, 0.4515, 0.4004, 0.4197],
#        device='cuda:0')
#  HS_EMBEDStensor([[ 8.2203e-01, -1.8291e-01,  4.2968e-04,  ..., -3.3196e+00,
#           3.9137e-02,  8.4723e-02],
#         [ 8.8120e-01, -1.7545e-01,  4.0210e-01,  ..., -3.3616e+00,
#           3.2711e-01, -1.8894e-01],
#         [ 7.0556e-01, -3.2411e-01,  3.2442e-01,  ..., -3.5950e+00,
#           3.1988e-01,  7.7000e-02],
#         ...,
#         [ 7.2658e-01, -9.0639e-01,  2.3171e-01,  ..., -3.1842e+00,
#           2.8455e-01,  2.7103e-01],
#         [ 6.4146e-01, -6.0316e-01,  2.5665e-01,  ..., -3.3394e+00,
#           1.0979e-01, -9.9569e-02],
# ...

# %%
# 3 encoder/decoder layers
# !python src/train.py with mot17 deformable multi_frame tracking resume=models/mot17_deformable_multi_frame/checkpoint_epoch_50.pth output_dir=models/custom_dataset_deformable/finetuned_layer mot_path_train=data/custom_dataset mot_path_val=data/custom_dataset train_split=train val_split=val enc_layers=3 dec_layers=3 epochs=5
# Out:
# Streaming output truncated to the last 5000 lines.
#  HS_EMBEDSTrue
#  INDICES: True
# POS: True
#  SCORES: True
#  HS_EMBEDSTrue
#  INDICES: True
# POS: True
#  SCORES: True
#  HS_EMBEDSTrue
#  INDICES: True
# POS: True
#  SCORES: True
#  HS_EMBEDSTrue
#  INDICES: True
# POS: True
#  SCORES: True
#  HS_EMBEDSTrue
#  INDICES: True
# POS: True
#  SCORES: True
#  HS_EMBEDSTrue
#  INDICES: True
# POS: True
#  SCORES: True
#  HS_EMBEDSTrue
#  INDICES: True
# POS: tensor([], device='cuda:0', size=(0, 4))
#  SCORES: tensor([], device='cuda:0')
#  HS_EMBEDStensor([], device='cuda:0', size=(0, 288))
#  72% 108/150 [00:11<00:04,  9.61it/s]POS: False
#  SCORES: False
#  HS_EMBEDSFalse
# POSTEST: tensor([[ 7.3522e+01,  2.5336e+02,  1.0785e+03,  6.3689e+02],
#         [ 3.3793e+02,  1.9204e+02,  3.9504e+02,  2.6239e+02],
#         [ 4.2017e+02, -1.5311e+01,  5.0515e+02,  5.9762e+01],
#         ...,
#         [ 6.7042e+02,  8.1076e+02,  7.1332e+02,  9.0152e+02],
# ...

# %%
# 4 encoder/decoder layers
# !python src/train.py with mot17 deformable multi_frame tracking resume=models/mot17_deformable_multi_frame/checkpoint_epoch_50.pth output_dir=models/custom_dataset_deformable/finetuned_layer mot_path_train=data/custom_dataset mot_path_val=data/custom_dataset train_split=train val_split=val enc_layers=4 dec_layers=4 epochs=5
# Out:
# Streaming output truncated to the last 5000 lines.
#  SCORES: True
#  HS_EMBEDSTrue
#  INDICES: True
# POS: True
#  SCORES: True
#  HS_EMBEDSTrue
#  INDICES: True
# POS: True
#  SCORES: True
#  HS_EMBEDSTrue
#  INDICES: True
# POS: True
#  SCORES: True
#  HS_EMBEDSTrue
#  INDICES: True
# POS: tensor([], device='cuda:0', size=(0, 4))
#  SCORES: tensor([], device='cuda:0')
#  HS_EMBEDStensor([], device='cuda:0', size=(0, 288))
#  73% 109/150 [00:12<00:04,  8.97it/s]POS: False
#  SCORES: False
#  HS_EMBEDSFalse
# POSTEST: tensor([[504.1402, 454.2691, 661.4712, 614.6580],
#         [ -1.7226, 135.6742, 331.8741, 263.7037],
#         [  2.2847, -41.5963, 199.9601,  55.7726],
#         ...,
#         [667.5513, 825.6462, 708.5696, 915.3860],
#         [712.5168, 440.1467, 824.8212, 553.4542],
#         [ -1.3446, 868.6260, 107.9559, 990.3699]], device='cuda:0')
#  SCORESTEST: tensor([0.0066, 0.0099, 0.0401, 0.0333, 0.0265, 0.0053, 0.0567, 0.1293, 0.0365,
# ...

# %%
# 5 encoder/decoder layers
# !python src/train.py with mot17 deformable multi_frame tracking resume=models/mot17_deformable_multi_frame/checkpoint_epoch_50.pth output_dir=models/custom_dataset_deformable/finetuned_layer mot_path_train=data/custom_dataset mot_path_val=data/custom_dataset train_split=train val_split=val enc_layers=5 dec_layers=5 epochs=5
# Out:
# Streaming output truncated to the last 5000 lines.
#        device='cuda:0')
# POS: False
#  SCORES: False
#  HS_EMBEDSFalse
# POS: True
#  SCORES: True
#  HS_EMBEDSTrue
#  INDICES: True
# POS: True
#  SCORES: True
#  HS_EMBEDSTrue
#  INDICES: True
# POS: True
#  SCORES: True
#  HS_EMBEDSTrue
#  INDICES: True
# POS: True
#  SCORES: True
#  HS_EMBEDSTrue
#  INDICES: True
# POS: True
#  SCORES: True
#  HS_EMBEDSTrue
#  INDICES: True
# POS: True
#  SCORES: True
#  HS_EMBEDSTrue
#  INDICES: True
# POS: True
#  SCORES: True
#  HS_EMBEDSTrue
#  INDICES: True
# POS: tensor([], device='cuda:0', size=(0, 4))
#  SCORES: tensor([], device='cuda:0')
#  HS_EMBEDStensor([], device='cuda:0', size=(0, 288))
#  75% 112/150 [00:14<00:04,  8.41it/s]POS: False
#  SCORES: False
#  HS_EMBEDSFalse
# POSTEST: tensor([[-55.9320, -97.0411, 967.9081, 926.9486],
#         [ 35.9933, 160.3813, 126.7309, 216.5729],
#         [401.2003, -12.7782, 471.6295,  24.1747],
#         ...,
# ...

# %%
import matplotlib.pyplot as plt

layers = [0, 1, 2, 3, 4, 5, 6]
mota_values = [0, 35.4, 64.4, 67.0, 72.3, 71.3, 73.3]

plt.figure(figsize=(8,6))
plt.plot(layers, mota_values, marker='o', linestyle='-', color='b')

plt.title('MOTA vs Number of Layers')
plt.xlabel('Number of Layers')
plt.ylabel('MOTA')

plt.savefig('layers_line_plot.png')
plt.show()
